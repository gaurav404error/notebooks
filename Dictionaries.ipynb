# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurav404error/notebooks/blob/main/Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
print(thisdict["brand"])
print(thisdict["model"])
print(thisdict["year"])
# Out:
# Ford
# Mustang
# 2000
# Ford
# Mustang
# 1964

# %%
# change the existing value
thisdict["year"] = 2000

# %%
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2000}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "years": 1964,
  "year": 2000
}

# %%
print(thisdict["years"])
# Out:
# 1964

# %%
len(thisdict)
# Out:
# 4

# %%
# keys()
for i in thisdict.keys():
  print(i)
# Out:
# brand
# model
# years
# year

# %%
# values()
for i in thisdict.values():
  print(i)
# Out:
# Ford
# Mustang
# 1964
# 2000

# %%
print(thisdict.items())
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('years', 1964), ('year', 2000)])

# %%
for key, value in thisdict.items():
  print(f"{key} : {value}")
# Out:
# brand : Ford
# model : Mustang
# years : 1964
# year : 2000

# %%
thisdict.update({"color":"black"})

# %%
thisdict
# Out:
# {'brand': 'Ford',
#  'model': 'Mustang',
#  'years': 1964,
#  'year': 2000,
#  'color': 'black'}

# %%
thisdict.update({"year":2122})

# %%
thisdict
# Out:
# {'brand': 'Ford',
#  'model': 'Mustang',
#  'years': 1964,
#  'year': 2122,
#  'color': 'black'}

# %%
thisdict.pop("years")
# Out:
# 1964

# %%
thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2122, 'color': 'black'}

# %%
thisdict.popitem()
# Out:
# ('color', 'black')

# %%
thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2122}

# %%
thisdict.popitem()
# Out:
# ('year', 2122)

# %%
thisdict.popitem()
# Out:
# ('model', 'Mustang')

# %%
del thisdict["brand"]

# %%
thisdict
# Out:
# {}

# %%
del thisdict

# %%
print(thisdict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1701145035.py in <cell line: 0>()
# ----> 1 print(thisdict)
#
# NameError: name 'thisdict' is not defined

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = thisdict.copy()
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
mydict["color"] = "blue"

# %%
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
mydict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'blue'}

# %%
# Make a copy of a dictionary with the dict() function:

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict_two = dict(thisdict)
print(mydict_two)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
m = thisdict

# %%
m.update({"color":"yellow"})

# %%
m
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'yellow'}

# %%
thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'yellow'}
